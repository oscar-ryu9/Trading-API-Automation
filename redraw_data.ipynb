# %%
from datetime import datetime, timedelta
import pandas as pd
import time
import pygame
import sys
import plotly.express as px
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
symbol = "BTCUSD"

data = pd.read_csv(symbol + ".csv")

# %%
cleaned_data = data.drop("Unnamed: 0", axis=1)
cleaned_data
# Out:
#            time      open      high       low     close  tick_volume  spread  \
# 0    2023-11-14  36484.00  36759.50  34659.55  35587.78       196727     368
# 1    2023-11-15  35596.46  37858.42  35362.70  37645.47       202043       0
# 2    2023-11-16  37635.99  37978.28  35494.85  35977.37       197942       0
# 3    2023-11-17  36047.87  36818.74  35852.84  36390.37       168352       0
# 4    2023-11-18  36429.02  36852.37  36195.73  36566.81       107790     655
# ..          ...       ...       ...       ...       ...          ...     ...
# 116  2024-03-09  68516.27  68700.75  68033.13  68570.91        87480       0
# 117  2024-03-10  68574.73  70025.60  68408.94  69445.06       115825       0
# 118  2024-03-11  69422.80  72860.16  67061.79  72085.76       243731     387
# 119  2024-03-12  72026.45  73079.18  68570.57  71033.73       206409       0
# 120  2024-03-13  70942.13  73705.14  70510.28  73176.19       210932       0
#
#      real_volume
# 0              0
# ...

# %%
def create_axes(screen, width, height):
    BLACK = (0, 0, 0)
    pygame.draw.line(screen, BLACK, (50, 50), (width - 50, 50), 2)  # Top line
    pygame.draw.line(screen, BLACK, (50, height - 50), (width - 50, height - 50), 2)  # Bottom line
    pygame.draw.line(screen, BLACK, (50, 50), (50, height - 50), 2)  # Left line
    pygame.draw.line(screen, BLACK, (width - 50, 50), (width - 50, height - 50), 2)  # Right line

# %%
background_color = (22,26,37)


pygame.init()
screen_width = 2050
screen_height = 1050
screen = pygame.display.set_mode((screen_width, screen_height))
pygame.display.set_caption("Pygame Window")

running = True
while running:
    # Handle events
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    # Clear the screen
    screen.fill(background_color)

    # Update the display
    pygame.display.flip()

    # Limit frame rate
    pygame.time.Clock().tick(60)

# Quit Pygame
pygame.quit()
